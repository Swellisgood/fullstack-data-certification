# %% [markdown]
# # Part 1 : Scraping information about cities

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"

import requests
import json
import pandas as pd
from bs4 import BeautifulSoup

import boto3
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, text

# %%
listCities = ["Mont Saint Michel",
                "St Malo",
                "Bayeux",
                "Le Havre",
                "Rouen",
                "Paris",
                "Amiens",
                "Lille",
                "Strasbourg",
                "Chateau du Haut Koenigsbourg",
                "Colmar",
                "Eguisheim",
                "Besancon",
                "Dijon",
                "Annecy",
                "Grenoble",
                "Lyon",
                "Gorges du Verdon",
                "Bormes les Mimosas",
                "Cassis",
                "Marseille",
                "Aix en Provence",
                "Avignon",
                "Uzes",
                "Nimes",
                "Aigues Mortes",
                "Saintes Maries de la mer",
                "Collioure",
                "Carcassonne",
                "Ariege",
                "Toulouse",
                "Montauban",
                "Biarritz",
                "Bayonne",
                "La Rochelle"]

# %%
df_cities = pd.DataFrame(listCities)
df_cities = df_cities.rename(columns={0: "Cities"})

# %%
url_cities = 'https://nominatim.openstreetmap.org/search.php?q={}&country=France&format=jsonv2'

latitude = []
longitude = []

for i in range(len(listCities)):
    search_cities = requests.get(url_cities.format(listCities[i]))
    latitude.append(search_cities.json()[0]['lat'])
    longitude.append(search_cities.json()[0]['lon'])

df_cities['latitude'] = latitude
df_cities['latitude'] = df_cities['latitude'].astype('float64')
df_cities['longitude'] = longitude
df_cities['longitude'] = df_cities['longitude'].astype('float64') 

df_cities.shape
display(df_cities.head())
# Out:
#               Cities   latitude  longitude
# 0  Mont Saint Michel  48.635954  -1.511460
# 1            St Malo  48.649518  -2.026041
# 2             Bayeux  49.276462  -0.702474
# 3           Le Havre  49.493898   0.107973
# 4              Rouen  49.440459   1.093966

# %%
# Storing cities data (needs to be collected only once)
df_cities.to_csv('data/cities.csv',index=False)

# %% [markdown]
# # Part 2 : Scraping information about weather

# %%
# API key and target url
api_key = open("data/openWeather_APIkey.txt", "r").read()
url_weather = "https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&exclude=current,minutely,hourly&units=metric&appid={}"

dataWeather = pd.DataFrame(columns=['Cities', 'latitude', 'longitude', 'main_weather_7days', 'rain_amount_7days', 'temp_7days','clouds_7days'])

# %%
df_cities
# Out:
#                           Cities   latitude  longitude
# 0              Mont Saint Michel  48.635954  -1.511460
# 1                        St Malo  48.649518  -2.026041
# 2                         Bayeux  49.276462  -0.702474
# 3                       Le Havre  49.493898   0.107973
# 4                          Rouen  49.440459   1.093966
# 5                          Paris  48.858890   2.320041
# 6                         Amiens  49.894171   2.295695
# 7                          Lille  50.636565   3.063528
# 8                     Strasbourg  48.584614   7.750713
# 9   Chateau du Haut Koenigsbourg  48.249490   7.344296
# 10                        Colmar  48.077752   7.357964
# 11                     Eguisheim  48.044797   7.307962
# 12                      Besancon  47.238022   6.024362
# 13                         Dijon  47.321581   5.041470
# 14                        Annecy  45.899235   6.128885
# 15                      Grenoble  45.187560   5.735782
# 16                          Lyon  45.757814   4.832011
# 17              Gorges du Verdon  43.749656   6.328562
# 18            Bormes les Mimosas  43.150697   6.341928
# 19                        Cassis  43.214036   5.539632
# 20                     Marseille  43.296174   5.369953
# 21               Aix en Provence  43.529842   5.447474
# 22                       Avignon  43.949249   4.805901
# 23                          Uzes  44.012128   4.419672
# 24                         Nimes  43.837425   4.360069
# 25                 Aigues Mortes  43.565823   4.191284
# 26      Saintes Maries de la mer  43.452277   4.428717
# 27                     Collioure  42.525050   3.083155
# 28                   Carcassonne  43.213036   2.349107
# 29                        Ariege  42.945537   1.406554
# 30                      Toulouse  43.604462   1.444247
# 31                     Montauban  44.017584   1.354999
# 32                      Biarritz  43.471144  -1.552727
# 33                       Bayonne  43.494514  -1.473666
# 34                   La Rochelle  46.159113  -1.152043

# %%
# for loop to request weather data
for i in range(len(df_cities)):
    req_weather = requests.get(url_weather.format(df_cities['latitude'][i], df_cities['longitude'][i], api_key))
    results = req_weather.json()

    predicted_rain = 0
    for row in results['daily']:
        if 'rain' in row.keys():
            predicted_rain += row['pop'] * row['rain']

# From weather API documentation, 'pop' = probability of precipitation, 'rain' is volume. 
    temperatures = pd.Series([row['temp']['day'] for row in results['daily']])
    weather = pd.Series([row['weather'][0]['main'] for row in results['daily']])
    cloudiness = pd.Series([row['clouds'] for row in results['daily']])

    mean_temperature = temperatures.mean()
    main_weather = weather.mode()[0]
    clouds = cloudiness.mean()


# Loading data into dataframe
    dataWeather.loc[i,'Cities'] = df_cities['Cities'][i]
    dataWeather.loc[i,'latitude'] = df_cities['latitude'][i]
    dataWeather.loc[i,'longitude'] = df_cities['longitude'][i]
    dataWeather.loc[i,'main_weather_7days'] = main_weather
    dataWeather.loc[i,'rain_amount_7days'] = int(predicted_rain)
    dataWeather.loc[i,'temp_7days'] = int(mean_temperature)
    dataWeather.loc[i,'clouds_7days'] = int(clouds)

# %% [markdown]
# Let's sort entries to get the most popular cities with the best weather. Then, we will rank their quality by temperature and humidity as well as cloudiness and wind speed.

# %%
dataWeather = dataWeather.sort_values(by=['rain_amount_7days', 'temp_7days','clouds_7days'], ascending=[True, False, True]).reset_index(drop=True)

dataWeather['quality'] = [round((dataWeather['temp_7days'][i]*2) - (dataWeather['clouds_7days'][i]/4) - (dataWeather['rain_amount_7days'][i]*2),2) for i in range(len(dataWeather))]
#  quality

dataWeather = dataWeather.sort_values(by='quality',ascending=False).reset_index(drop=True)

display(dataWeather)
# Out:
#                           Cities   latitude longitude main_weather_7days  \
# 0                      Collioure   42.52505  3.083155             Clouds
# 1                         Cassis  43.214036  5.539632             Clouds
# 2             Bormes les Mimosas  43.150697  6.341928             Clouds
# 3                      Marseille  43.296174  5.369953             Clouds
# 4                  Aigues Mortes  43.565823  4.191284             Clouds
# 5                    Carcassonne  43.213036  2.349107             Clouds
# 6                Aix en Provence  43.529842  5.447474             Clouds
# 7       Saintes Maries de la mer  43.452277  4.428717             Clouds
# 8                       Toulouse  43.604462  1.444247               Rain
# 9                        Avignon  43.949249  4.805901             Clouds
# 10                         Nimes  43.837425  4.360069             Clouds
# 11                          Uzes  44.012128  4.419672             Clouds
# 12                     Montauban  44.017584  1.354999               Rain
# 13              Gorges du Verdon  43.749656  6.328562             Clouds
# 14                        Ariege  42.945537  1.406554             Clouds
# 15                      Grenoble   45.18756  5.735782               Rain
# 16                         Paris   48.85889  2.320041               Rain
# 17                         Dijon  47.321581   5.04147               Rain
# 18                    Strasbourg  48.584614  7.750713               Rain
# 19                      Biarritz  43.471144 -1.552727               Rain
# 20                       Bayonne  43.494514 -1.473666               Rain
# 21                          Lyon  45.757814  4.832011             Clouds
# 22                   La Rochelle  46.159113 -1.152043               Rain
# 23                        Colmar  48.077752  7.357964               Rain
# 24                      Besancon  47.238022  6.024362               Rain
# 25                     Eguisheim  48.044797  7.307962               Rain
# 26  Chateau du Haut Koenigsbourg   48.24949  7.344296               Rain
# 27                        Amiens  49.894171  2.295695               Rain
# 28                         Lille  50.636565  3.063528               Rain
# 29                        Bayeux  49.276462 -0.702474               Rain
# 30                         Rouen  49.440459  1.093966               Rain
# 31                        Annecy  45.899235  6.128885               Rain
# 32                       St Malo  48.649518 -2.026041               Rain
# 33             Mont Saint Michel  48.635954  -1.51146               Rain
# 34                      Le Havre  49.493898  0.107973               Rain
#
#    rain_amount_7days temp_7days clouds_7days  quality
# 0                  0         14           71    10.25
# 1                  6         14           52     3.00
# 2                  5         14           61     2.75
# 3                  7         14           52     1.00
# 4                  5         13           66    -0.50
# 5                  1         12           91    -0.75
# 6                  7         13           53    -1.25
# 7                  6         13           63    -1.75
# 8                  5         12           83    -6.75
# 9                 11         14           69   -11.25
# 10                10         13           70   -11.50
# 11                11         12           71   -15.75
# 12                 9         12           88   -16.00
# 13                10         10           69   -17.25
# 14                 7          8           92   -21.00
# 15                14         13           87   -23.75
# 16                15         10           96   -34.00
# 17                18         10           84   -37.00
# 18                22         10           82   -44.50
# 19                28         14           87   -49.75
# 20                28         14           87   -49.75
# 21                27         12           81   -50.25
# 22                26         12           96   -52.00
# 23                28         11           79   -53.75
# 24                28         11           83   -54.75
# 25                30         11           79   -57.75
# 26                27          8           81   -58.25
# 27                30         10           85   -61.25
# 28                32          9           88   -68.00
# 29                36         11           91   -72.75
# 30                36         10           87   -73.75
# 31                38         10           79   -75.75
# 32                38         11           95   -77.75
# 33                44         11           95   -89.75
# 34                49         10           94  -101.50

# %%
# dataWeather.to_csv('data/dataWeather.csv',index=False)
dataWeather = pd.read_csv('data/dataWeather.csv')

# %% [markdown]
# # Part 3 : Scraping information about hotels

# %% [markdown]
# Let's scrape informations about hotels in the most popular cities with the best weather. Getting search urls (Booking.com page) for each city, displaying only results with score above 6 / 10.
# Getting hotels' URLs for each search :

# %%
agent = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
search_urls = []

for i in range(len(dataWeather)):
    search_urls.append('https://www.booking.com/searchresults.fr.html?ss='+dataWeather['Cities'][i]+'&nflt=review_score%3D60')

hotels_urls = []

for url in search_urls:
    page = requests.get(url, headers=agent)
    soup = BeautifulSoup(page.content, "html.parser")
    for a in soup.find_all('a',{"class": "e13098a59f"}, href=True):
        hotels_urls.append(a['href'])


hotels_urls = [i.split('?')[0] for i in hotels_urls]

# %% [markdown]
# Now let's create a class to store all the informations about the cities. We will use this class to create a dataframe. Finally, we will use this dataframe to create a marker map.

# %%
class BookingHotelData:
    '''Class to get hotel data from booking.com, using hotel url, and store it in a dictionary.'''
    def __init__(self):
        '''Initiate the class, and create a list of hotels urls and a dictionary to store hotel data.'''
        self.hotel_list = []
        self.hotel_data = {}
        self.hotel_data["name"] = "Empty"
        self.hotel_data["address"] = "Empty"
        self.hotel_data["description"] = "Empty"
        self.hotel_data["score"] = "Empty"
        self.hotel_data["url"] = "Empty"
        self.hotel_data["bonus"] = "Empty"
        self.hotel_data["latlon"] = "Empty"

    def get_hotel_data(self, url):
        '''Get hotel data from booking.com, using hotel url, and store it in a dictionary.'''
        agent = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
        session_object = requests.Session()
        page = session_object.get(url,headers=agent)
        soup = BeautifulSoup(page.content, "lxml")
        try:
            self.hotel_data["name"] = soup.find("h2", {"class": "pp-header__title"}).text.strip()
        except:
            pass
        try:
            self.hotel_data["address"] = soup.find("span", {"class": "hp_address_subtitle"}).text.strip()
        except:
            pass
        try:
            self.hotel_data["description"] = soup.find("div", {"class": "hp_desc_main_content"}).text.strip()
        except:
            pass
        try:
            self.hotel_data["score"] = soup.find("a", {"class": "hp_review_score"}).text.strip()
        except:
            pass
        try:
             self.hotel_data["bonus"] = soup.find("div", {"class": "hp_desc_important_facilities"}).text.strip()
        except:
            pass
        try:
             self.hotel_data["latlon"] = soup.find("a", {"class": "show_map"}).get('data-atlas-latlng')
        except:
            pass

        self.hotel_data["url"] = url
        
        self.hotel_list.append(self.hotel_data)

# %%
print(len(hotels_urls))
# Out:
# 875

# %% [markdown]
# After scraping the data, we will save it in a csv file. We will use the pandas library to save the data in a csv file.

# %%
# Getting hotel data from each hotel url, and storing it in a list of dictionaries. 
hotels_list = []
count = 0

for url in hotels_urls:
    count = count
    hotels = BookingHotelData()
    hotels.get_hotel_data(url)
    hotels_list.append(hotels.hotel_list[:])
    count += 1
    if count % 50 == 0:
        print(count)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850

# %%
dataBooking = dataWeather.copy()
dataBooking = dataBooking.loc[dataWeather.index.repeat(25)]
dataBooking = dataBooking.drop(['latitude','longitude','main_weather_7days','rain_amount_7days','temp_7days','clouds_7days','quality'],axis=1)

# Creating new df with hotel info
dataBooking['raw_data'] = hotels_list
dataBooking['raw_data'] = dataBooking['raw_data'].apply(pd.Series)

hotel_data = dataBooking.raw_data.apply(pd.Series)
dataBooking = pd.concat([dataBooking, hotel_data],axis=1)
dataBooking = dataBooking.drop('raw_data', axis=1).reset_index()

dataBooking['description'] = dataBooking['description'].str.replace('\n', '')
dataBooking['score'] = dataBooking['score'].str.replace('\xa0', '').str.slice(stop=3)
dataBooking['score'] = dataBooking['score'].str.replace(',', '.')

dataBooking['bonus'] = dataBooking['bonus'].str.replace('\n', ' ').str.replace('Ses points forts', '')
dataBooking['latitude'] = dataBooking['latlon'].str.split(',').str[0]
dataBooking['longitude'] = dataBooking['latlon'].str.split(',').str[1]
dataBooking = dataBooking.drop('latlon',axis=1)
dataBooking[['latitude','longitude']] = dataBooking[['latitude','longitude']].astype(float)

# %%
dataBooking['score'] = dataBooking['score'].str.replace(',', '.') # Replace comma by dot
#drop index column
dataBooking = dataBooking.drop('index',axis=1)

# Checking for missing data
dataBooking.isna().sum()
# Out:
# Cities         0
# name           0
# address        0
# description    0
# score          0
# url            0
# bonus          0
# latitude       0
# longitude      0
# dtype: int64

# %%
# Storing hotels data (needs to be collected only once)
dataBooking.to_csv('data/dataBooking.csv',index=False)

# %%
# uncomment to load data
# dataBooking = pd.read_csv('data/dataBooking.csv')

# %%
dataBooking.head()
# Out:
#       Cities                                       name  \
# 0  Collioure                    Résidence Saint Vincent
# 1  Collioure                          Les Roches Brunes
# 2  Collioure                                 La Frégate
# 3  Collioure  Bel appartement pour 4 personnes - 4SAP22
# 4  Collioure                     Le Mas des Citronniers
#
#                                              address  \
# 0       9 rue saint vincent, 66190 Collioure, France
# 1     Route de Port-Vendres, 66190 Collioure, France
# 2  24 Boulevard Camille Pelletan, 66190 Collioure...
# 3  residence Saphir Route Imperiale 1b, 66190 Col...
# 4  22 Avenue de La Republique, 66190 Collioure, F...
#
#                                          description score  \
# 0  Vous pouvez bénéficier d'une réduction Genius ...   8.0
# 1  Vous pouvez bénéficier d'une réduction Genius ...   9.1
# 2  Situé à Collioure, à 200 mètres de la plage de...   8.2
# 3  Vous pouvez bénéficier d'une réduction Genius ...   7.8
# 4  Vous pouvez bénéficier d'une réduction Genius ...   8.0
#
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/residence-sai...
# 1  https://www.booking.com/hotel/fr/les-roches-br...
# 2  https://www.booking.com/hotel/fr/la-fra-c-gate...
# 3  https://www.booking.com/hotel/fr/residence-sap...
# 4  https://www.booking.com/hotel/fr/lesmasdescitr...
#
#                                                bonus   latitude  longitude
# 0      Parking    Connexion Wi-Fi gratuite    Cha...  42.527301   3.084233
# 1      Parking gratuit    Restaurant    Chambres ...  42.525348   3.090324
# 2      Animaux domestiques admis    Restaurant   ...  42.526386   3.083257
# 3      Parking gratuit    Front de mer    Chambre...  42.524349   3.090149
# 4      Animaux domestiques admis    Connexion Wi-...  42.525382   3.082564

# %% [markdown]
# # Part 4 : Storing the data in AWS S3 and querying it

# %% [markdown]
# Data is now scraped and saved in a csv file. Let's now store it in AWS S3 bucket. We will use boto3 library to store the data in S3 bucket. We will use the following code to store the data in S3 bucket.

# %%
# Create a session on amazon S3
aws_settings = open("data/AWSsettings.txt", "r").readlines()

session = boto3.Session(
                        aws_access_key_id= aws_settings[0].strip(),
                        aws_secret_access_key= aws_settings[1].strip()
                        )

s3 = session.resource("s3")

# %%
#create a bucket
bucketname = 'bucketswell-bookingcom'
bucket = s3.create_bucket(Bucket=bucketname, ACL = 'public-read-write', CreateBucketConfiguration={'LocationConstraint': 'eu-west-3'})

# %%
s3.Bucket(bucketname).upload_file('data/dataBooking.csv','dataBooking.csv')
s3.Bucket(bucketname).upload_file('data/dataWeather.csv','dataWeather.csv')

# %%
import io

#getting the file from the bucket and storing it in a dataframe
obj = s3.Object(bucketname, 'dataBooking.csv')
body = obj.get()['Body'].read()
bucket_booking = pd.read_csv(io.BytesIO(body))

obj = s3.Object(bucketname, 'dataWeather.csv')
body = obj.get()['Body'].read()
bucket_weather = pd.read_csv(io.BytesIO(body))

# %%
bucket_booking.head()
# Out:
#       Cities                                       name  \
# 0  Collioure                    Résidence Saint Vincent
# 1  Collioure                          Les Roches Brunes
# 2  Collioure                                 La Frégate
# 3  Collioure  Bel appartement pour 4 personnes - 4SAP22
# 4  Collioure                     Le Mas des Citronniers
#
#                                              address  \
# 0       9 rue saint vincent, 66190 Collioure, France
# 1     Route de Port-Vendres, 66190 Collioure, France
# 2  24 Boulevard Camille Pelletan, 66190 Collioure...
# 3  residence Saphir Route Imperiale 1b, 66190 Col...
# 4  22 Avenue de La Republique, 66190 Collioure, F...
#
#                                          description score  \
# 0  Vous pouvez bénéficier d'une réduction Genius ...   8.0
# 1  Vous pouvez bénéficier d'une réduction Genius ...   9.1
# 2  Situé à Collioure, à 200 mètres de la plage de...   8.2
# 3  Vous pouvez bénéficier d'une réduction Genius ...   7.8
# 4  Vous pouvez bénéficier d'une réduction Genius ...   8.0
#
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/residence-sai...
# 1  https://www.booking.com/hotel/fr/les-roches-br...
# 2  https://www.booking.com/hotel/fr/la-fra-c-gate...
# 3  https://www.booking.com/hotel/fr/residence-sap...
# 4  https://www.booking.com/hotel/fr/lesmasdescitr...
#
#                                                bonus   latitude  longitude
# 0      Parking    Connexion Wi-Fi gratuite    Cha...  42.527301   3.084233
# 1      Parking gratuit    Restaurant    Chambres ...  42.525348   3.090324
# 2      Animaux domestiques admis    Restaurant   ...  42.526386   3.083257
# 3      Parking gratuit    Front de mer    Chambre...  42.524349   3.090149
# 4      Animaux domestiques admis    Connexion Wi-...  42.525382   3.082564

# %%
bucket_weather.head()
# Out:
#                Cities   latitude  longitude main_weather_7days  \
# 0           Collioure  42.525050   3.083155             Clouds
# 1              Cassis  43.214036   5.539632             Clouds
# 2  Bormes les Mimosas  43.150697   6.341928             Clouds
# 3           Marseille  43.296174   5.369953             Clouds
# 4       Aigues Mortes  43.565823   4.191284             Clouds
#
#    rain_amount_7days  temp_7days  clouds_7days  quality
# 0                  0          14            71    10.25
# 1                  6          14            52     3.00
# 2                  5          14            61     2.75
# 3                  7          14            52     1.00
# 4                  5          13            66    -0.50

# %%
# Getting login info from file to avoid putting it on github by accident
login_info = open("data/login_info.txt", "r").readlines()

engine = create_engine(f"postgresql+psycopg2://{login_info[0].strip()}:{login_info[1].strip()}@{login_info[2].strip()}:{login_info[3].strip()}/{login_info[4].strip()}")
Session = sessionmaker(bind=engine)
session = Session()

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@kayak-1.chnczk8u9ur3.eu-west-3.rds.amazonaws.com:5432/postgres)

# %%
# storing weather & booking dataframes as SQL tables
dataWeather.to_sql('weather', con=engine, if_exists='replace', index=False)
dataBooking.to_sql('booking', con=engine, if_exists='replace', index=False)

# %% [markdown]
# # Part 5 : Creating a marker map of Top 5 cities by quality score, and the top 20 hotels in each city by booking.com score

# %%
selected_cities = dataWeather.iloc[:5,:]

# %%
selected_cities['quality'] = abs(selected_cities['quality'])
# Out:
# C:\Users\swell\AppData\Local\Temp\ipykernel_6252\271658625.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.scatter_mapbox(selected_cities, lat="latitude", lon="longitude", hover_name = 'Cities', zoom = 5,
                        hover_data={
                                    'latitude': False,
                                    'longitude': False,
                                    'quality': True,
                                    'temp_7days': True,
                                    'rain_amount_7days': True,
                                    'main_weather_7days': True
                                    },
                        color = 'temp_7days', color_continuous_scale = px.colors.sequential.Rainbow, size='quality', center={"lat": 46.2276, "lon": 2.2137},
                        mapbox_style='open-street-map',width = 1050, height = 800,
                        title='Cities with best weather in France for the last 7 days')
fig.show()
# Out:
# <div>                            <div id="ad957bdd-b43d-43dc-8d63-9dc7650fb1af" class="plotly-graph-div" style="height:800px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad957bdd-b43d-43dc-8d63-9dc7650fb1af")) {                    Plotly.newPlot(                        "ad957bdd-b43d-43dc-8d63-9dc7650fb1af",                        [{"customdata":[[42.52505,3.0831554,10.25,14,0,"Clouds"],[43.2140359,5.5396318,3.0,14,6,"Clouds"],[43.1506968,6.3419285,2.75,14,5,"Clouds"],[43.2961743,5.3699525,1.0,14,7,"Clouds"],[43.5658225,4.1912837,0.5,13,5,"Clouds"]],"hovertemplate":"<b>%{hovertext}</b><br><br>quality=%{customdata[2]}<br>temp_7days=%{marker.color}<br>rain_amount_7days=%{customdata[4]}<br>main_weather_7days=%{customdata[5]}<extra></extra>","hovertext":["Collioure","Cassis","Bormes les Mimosas","Marseille","Aigues Mortes"],"lat":[42.52505,43.2140359,43.1506968,43.2961743,43.5658225],"legendgroup":"","lon":[3.0831554,5.5396318,6.3419285,5.3699525,4.1912837],"marker":{"color":[14,14,14,14,13],"coloraxis":"coloraxis","size":[10.25,3.0,2.75,1.0,0.5],"sizemode":"area","sizeref":0.025625},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoor ...

# %%
#merge weather and selected cities dataframes on cities coordinates and drop redundant columns
selected_cities_hotels = pd.merge(selected_cities['Cities'], dataBooking, on=['Cities'], how='inner')

# %%
selected_cities_hotels
# Out:
#             Cities                                              name  \
# 0        Collioure                           Résidence Saint Vincent
# 1        Collioure                                 Les Roches Brunes
# 2        Collioure                                        La Frégate
# 3        Collioure         Bel appartement pour 4 personnes - 4SAP22
# 4        Collioure                            Le Mas des Citronniers
# ..             ...                                               ...
# 120  Aigues Mortes                                       Mas Tarquin
# 121  Aigues Mortes                                    Hotel L'Escale
# 122  Aigues Mortes  Marina 120m²/8 pers/ terrasse 100m²/ appontement
# 123  Aigues Mortes                      Chambre à 500 m des remparts
# 124  Aigues Mortes               CABANE DU SAUNIER MAIA ETANG DU ROY
#
#                                                address  \
# 0         9 rue saint vincent, 66190 Collioure, France
# 1       Route de Port-Vendres, 66190 Collioure, France
# 2    24 Boulevard Camille Pelletan, 66190 Collioure...
# 3    residence Saphir Route Imperiale 1b, 66190 Col...
# 4    22 Avenue de La Republique, 66190 Collioure, F...
# ..                                                 ...
# 120  121 Chemin de Cartouche, 30220 Aigues-Mortes, ...
# 121         6 rue du Port, 30220 Aigues-Mortes, France
# 122  7 1015 Avenue de la Mont Joye, 30220 Aigues-Mo...
# 123  551 Chemin du Bosquet, 30220 Aigues-Mortes, Fr...
# 124  SALINS D'AIGUES MORTES, Route du Grau du Roi, ...
#
#                                            description score  \
# 0    Vous pouvez bénéficier d'une réduction Genius ...   8.0
# 1    Vous pouvez bénéficier d'une réduction Genius ...   9.1
# 2    Situé à Collioure, à 200 mètres de la plage de...   8.2
# 3    Vous pouvez bénéficier d'une réduction Genius ...   7.8
# 4    Vous pouvez bénéficier d'une réduction Genius ...   8.0
# ..                                                 ...   ...
# 120  Doté d'un jardin et d'une terrasse, le Mas Tar...   9.0
# 121  Situé à Aigues-Mortes, à moins de 23 km de la ...   8.1
# 122  Boasting a garden, a shared lounge, and a terr...   Exc
# 123  Offrant une vue sur son jardin, la Chambre à 5...   9.7
# 124  Le CABANE DU SAUNIER MAIA ETANG DU ROY est sit...   9.2
#
#                                                    url  \
# 0    https://www.booking.com/hotel/fr/residence-sai...
# 1    https://www.booking.com/hotel/fr/les-roches-br...
# 2    https://www.booking.com/hotel/fr/la-fra-c-gate...
# 3    https://www.booking.com/hotel/fr/residence-sap...
# 4    https://www.booking.com/hotel/fr/lesmasdescitr...
# ..                                                 ...
# 120  https://www.booking.com/hotel/fr/frederic-aigu...
# 121  https://www.booking.com/hotel/fr/l-39-escale-a...
# 122  https://www.booking.com/hotel/fr/marina-120m2-...
# 123  https://www.booking.com/hotel/fr/valerie-aigue...
# 124  https://www.booking.com/hotel/fr/cabane-du-sau...
#
#                                                  bonus   latitude  longitude
# 0        Parking    Connexion Wi-Fi gratuite    Cha...  42.527301   3.084233
# 1        Parking gratuit    Restaurant    Chambres ...  42.525348   3.090324
# 2        Animaux domestiques admis    Restaurant   ...  42.526386   3.083257
# 3        Parking gratuit    Front de mer    Chambre...  42.524349   3.090149
# 4        Animaux domestiques admis    Connexion Wi-...  42.525382   3.082564
# ..                                                 ...        ...        ...
# 120      Parking gratuit    Animaux domestiques adm...  43.561044   4.217806
# 121      Parking gratuit    Animaux domestiques adm...  43.568796   4.188087
# 122      Parking gratuit    Connexion Wi-Fi gratuit...  43.575428   4.187291
# 123      Parking gratuit    Connexion Wi-Fi gratuit...  43.565819   4.205353
# 124            Parking gratuit    Chambres non-fumeurs  43.557539   4.182397
#
# [125 rows x 9 columns]

# %%
#replace rows with score = 'Exc' (exceptionnal) by 9.5
selected_cities_hotels['score'] = selected_cities_hotels['score'].replace('Exc', 9.5)

#display unique values in score column
selected_cities_hotels['score'].unique()

#convert score column to float
selected_cities_hotels['score'] = selected_cities_hotels['score'].astype(float)

# %%
fig = px.scatter_mapbox(selected_cities_hotels, lat="latitude", lon="longitude", hover_name = 'Cities', zoom = 6.5,
                        hover_data={
        'latitude': False,
        'longitude': False,
        'name': True,
        'address': True,
        'score': True,
        'bonus': True,
        }, 
                        color = 'Cities', color_discrete_sequence = px.colors.sequential.Inferno, template='plotly', size='score',
                        mapbox_style='open-street-map',width = 1050, height = 900,
                        title='Best rated hotels in selected cities (with the best weather in the last 7 days)')
fig.show()
# Out:
# <div>                            <div id="27183764-d9b2-4123-80d7-f6cca54a938b" class="plotly-graph-div" style="height:900px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27183764-d9b2-4123-80d7-f6cca54a938b")) {                    Plotly.newPlot(                        "27183764-d9b2-4123-80d7-f6cca54a938b",                        [{"customdata":[[42.52730095,3.08423268,"R\u00e9sidence Saint Vincent","9 rue saint vincent, 66190 Collioure, France",8.0,"    Parking    Connexion Wi-Fi gratuite    Chambres familiales    Chambres non-fumeurs    Enregistrement en ligne disponible"],[42.52534777,3.09032446,"Les Roches Brunes","Route de Port-Vendres, 66190 Collioure, France",9.1,"    Parking gratuit    Restaurant    Chambres familiales    Chambres non-fumeurs    Terrasse    Plateau/bouilloire dans tous les h\u00e9bergements    Bar"],[42.52638625,3.08325659,"La Fr\u00e9gate","24 Boulevard Camille Pelletan, 66190 Collioure, France",8.2,"    Animaux domestiques admis    Restaurant    Chambres non-fumeurs    Terrasse    Bar"],[42.52434874,3.09014887,"Bel appartement pour 4 personnes - 4SAP22","residence Saphir Route Imperiale 1b, 66190 Collioure, France",7.8,"    Parking gratuit    Front de mer    Chambres familiales    Chambres non-fumeurs    Terrasse"],[42.52538159,3.08256391,"Le Mas des Citronniers","22 Avenue de La Republique, 66190 Collioure, France",8.0,"    Animaux domestiques admis    Connexion Wi-Fi gratuite    Chambres familiales    Chambres non-fumeurs"],[42.52371617,3.08713473,"H\u00f4tel Triton","Rue Jean Bart, 66190 Collioure, France",7.2,"    Animaux domestiques admis    Connexion Wi-Fi gratuite    Front de mer    Chambres familiales    Chambres non-fumeurs    Terrasse"],[42.52311754,3.0854253,"R\u00e9sidence du Soleil","B 7 Rue du Soleil, 66190 Collioure, France",7.8,"    Parking gratuit    Animaux domestiques admis    Spa et centre de bien-\u00eatre    Connexion Wi-Fi gratuite    Front de mer    Chambres familiales"],[42.52439,3.082726,"Les Suites de Collioure","16 avenue du G\u00e9n\u00e9ral de Gaulle, 66190 Collioure, France",9.4,"    Parking    Connexion Wi-Fi gratuite    Chambres familiales    Chambres non-fumeurs"],[42.52708254,3.08026291,"Hotel M\u00e9diterran\u00e9e","Avenue Aristide Maillol, 66190 Collioure, France",7.7,"    Parking    Animaux domestiques admis    Connexion Wi-Fi gratuite    Chambres non-fumeurs    Terrasse"],[42.52876467,3.07865426,"Le Madeloc H\u00f4tel & Spa","24 Rue Romain Rolland, 66190 Collioure, France",8.8,"    1 piscine    Parking    Animaux domestiques admis    Spa et centre de bien-\u00eatre    Connexion Wi-Fi gratuite    Chambres familiales    Plateau/bouilloire dans tous les h\u00e9bergements"],[42.52616733,3.08235571,"H\u00f4tel La Casa Pairal","Impasse Des Palmiers, 66190 Collioure, France",8.8,"    1 piscine    Parking    Animaux domestiques admis    Connexion Wi-Fi gratuite    Chambres familiales"],[42.52507267,3.09015687,"Residence Les Balcons de Collioure - maeva Home","28 Route de Port-Vendres, 66190 Collioure, France",7.2,"    1 piscine    Parking    Animaux domestiques admis    Chambres familiales    Chambres non-fumeurs"],[42.52591431,3.0826816,"H\u00f4tel Princes de Catalogne","Rue Des Palmiers, 66190 Collioure, France",7.9,"    Parking    Animaux domestiques admis    Connexion Wi-Fi gratuite    Chambres familiales    Chambres non-fumeurs    \u00c9quipements pour les personnes handicap\u00e9es"],[42.5238821,3.0844023,"Appartement de charme \u00e0 50m de la plage de sable","4 Rue Nungesser et Coli, 66190 Collioure, France",8.5,"    Parking    Animaux domestiques admis    Connexion Wi-Fi gratuite    Front de mer    Chambres non-fumeurs"],[42.5273935,3.0847579,"Au coeur de Collioure","6, Rue Ri\u00e8re, 66190 Collioure, France",9.3,"    Animaux domestiques admis    Connexion Wi-Fi  ...
